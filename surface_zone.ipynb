# %% [markdown]
# # Název
# totagjer qnnn fo

# %%
import matplotlib.pyplot as plt
import numpy as np
a =5
print(a)
# Out:
# 5

# %%
x = np.linspace(0,1,100)
plt.plot(x, x**2,x*3)
plt.show()
plt.legend()
# Out:
# No handles with labels found to put in legend.

# %% [markdown]
# $ \sin(x) = \frac{\pi}{2} $
