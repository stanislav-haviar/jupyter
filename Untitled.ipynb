# %% [markdown]
# # Název
# totagjer qnnn fo

# %%
import matplotlib.pyplot as plt
import numpy as np
a =5
print(a)
# Out:
# 5

# %%
x = np.linspace(0,1,100)
plt.plot(x, x**2)
plt.show()

# %% [markdown]
# $ \sin(x) = \frac{\pi}{2} $
